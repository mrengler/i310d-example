# %% [markdown]
# ## Restaurant Inspections
#
# Below we are going to analyze some data from Austin area restaurant inspections.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Restaurant_Inspection_Scores.csv')

# %%
df.head()
# Out:
#                     Restaurant Name Zip Code Inspection Date  Score  \
# 0              Williams Sonoma #706    78746      06/16/2015     85
# 1                         Whisler's    78702      01/06/2015     83
# 2                  Whataburger #347    78757      06/03/2016     97
# 3            Westin Austin Downtown    78701      03/07/2016     76
# 4  Whistle Stop Grocery/La Mexicana    78753      05/18/2015     81
#
#                                              Address  Facility ID  \
# 0  2901 S CAPITAL OF TEXAS HWY NB\nAUSTIN, TX 787...      2801932
# 1  1816 E 6TH ST\nAUSTIN, TX 78702\n(30.261738, -...     10928995
# 2  2801 W ANDERSON LN\nAUSTIN, TX 78757\n(30.3589...      2800287
# 3  310 E 5TH ST\nAUSTIN, TX 78701\n(30.26632, -97...     11377565
# 4  834 E RUNDBERG LN Bldg B\nAUSTIN, TX 78753\n(3...      2803636
#
#   Process Description
# 0  Routine Inspection
# 1  Routine Inspection
# 2  Routine Inspection
# 3  Routine Inspection
# 4  Routine Inspection

# %%
print(len(df))
# Out:
# 25033

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df['Restaurant Name']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['Restaurant Name'][0]
# Out:
# 'Williams Sonoma #706'

# %%
for col in df.columns:
    print(col, type(df[col][0]))
# Out:
# Restaurant Name <class 'str'>
# Zip Code <class 'str'>
# Inspection Date <class 'str'>
# Score <class 'numpy.int64'>
# Address <class 'str'>
# Facility ID <class 'numpy.int64'>
# Process Description <class 'str'>

# %%
df.describe()
# Out:
#               Score   Facility ID
# count  25033.000000  2.503300e+04
# mean      91.360644  7.546523e+06
# std        7.643576  3.867410e+06
# min       36.000000  2.800004e+06
# 25%       87.000000  2.802178e+06
# 50%       93.000000  1.017732e+07
# 75%       97.000000  1.081075e+07
# max      100.000000  1.156976e+07

# %%
import matplotlib.pyplot as plt

df.hist(column='Score')
plt.ylabel('Number of Observations')
# Out:
# Text(0, 0.5, 'Number of Observations')

# %% [markdown]
# This plot shows the distribution of inspection scores received. As we can see, the most common range of scores is 90 to 100.

# %%
df['Zip Code'].value_counts()
# Out:
# 78701                          1742
# 78758                          1580
# 78704                          1544
# 78745                          1364
# 78753                          1063
# 78757                          1045
# 78705                          1044
# 78759                          1042
# 78702                          1038
# 78749                           774
# 78741                           756
# 78748                           732
# 78746                           723
# 78723                           682
# 78744                           623
# 78738                           550
# 78731                           541
# 78703                           524
# 78751                           522
# 78729                           470
# 78752                           464
# 78750                           453
# 78756                           425
# 78727                           404
# 78660                           384
# 78735                           378
# 78734                           372
# 78653                           311
# 78726                           307
# 78717                           304
# 78728                           293
# 78617                           276
# 78732                           274
# 78754                           249
# 78722                           244
# 78613                           231
# 78721                           183
# 78719                           167
# 78724                           162
# 78669                           132
# 78730                            92
# 78747                            79
# 78737                            75
# 78736                            75
# 78725                            66
# 78739                            64
# 78652                            56
# 78733                            48
# 78641                            27
# 78742                            24
# 78620                            24
# 78612                             8
# 78654                             7
# 78615                             6
# 6\nAustin, TX  78741              5
# Hwy 290 E\nAustin TX  78723       5
# Name: Zip Code, dtype: int64

# %%
df[df['Score']==100]
# Out:
#                                Restaurant Name Zip Code Inspection Date  \
# 7                           Webb Middle School    78752      09/18/2014
# 8                     Westlake PAC Concessions    78746      10/14/2016
# 9                     West Ridge Middle School    78733      11/25/2014
# 14                Wild Bubba's Wild Game Grill    78617      08/06/2014
# 17                             Wayside Schools    78745      10/13/2016
# ...                                        ...      ...             ...
# 25026                             Water 2 Wine    78704      09/20/2016
# 25027           WL - Randall's #2477-Starbucks    78746      03/14/2016
# 25028             WL - P. Terry's Burger Stand    78746      01/28/2015
# 25029                    WL - Walgreens #06050    78746      06/18/2014
# 25030  Wal-Mart Supercenter/Meat&Seafood #1185    78753      11/20/2014
#
#        Score                                            Address  Facility ID  \
# 7        100  601 E ST JOHNS AVE\nAUSTIN, TX 78752\n(30.3339...      2800006
# 8        100  4100 WESTBANK DR\nWEST LAKE HILLS, TX 78746\n(...     10334733
# 9        100  9201 SCENIC BLUFF DR\nAUSTIN, TX 78733\n(30.30...      2800695
# 14       100  13912 FM 812 RD\nAUSTIN, TX 78617\n(30.120788,...     10015202
# 17       100  6215 MANCHACA RD\nAUSTIN, TX 78745\n(30.209943...     11053776
# ...      ...                                                ...          ...
# 25026    100  4036 S LAMAR BLVD SB Unit 100\nAUSTIN, TX 7870...     10902652
# 25027    100  3300 BEE CAVES RD\nWEST LAKE HILLS, TX 78746\n...     10223149
# 25028    100  701 S CAPITAL OF TEXAS HWY NB Unit H\nWEST LAK...     10771894
# 25029    100  3700 BEE CAVES RD\nWEST LAKE HILLS, TX 78746\n...     10005361
# 25030    100  1030 NORWOOD PARK BLVD\nAUSTIN, TX 78753\n(30....      2803919
#
#       Process Description
# 7      Routine Inspection
# 8      Routine Inspection
# 9      Routine Inspection
# 14     Routine Inspection
# 17     Routine Inspection
# ...                   ...
# 25026  Routine Inspection
# 25027  Routine Inspection
# 25028  Routine Inspection
# 25029  Routine Inspection
# 25030  Routine Inspection
#
# [3980 rows x 7 columns]

# %%
df[df['Zip Code']=='Hwy 290 E\nAustin TX  78723']
# Out:
#       Restaurant Name                     Zip Code Inspection Date  Score  \
# 11074        Circle A  Hwy 290 E\nAustin TX  78723      12/14/2016     97
# 11587        Circle A  Hwy 290 E\nAustin TX  78723      02/25/2015     82
# 11661        Circle A  Hwy 290 E\nAustin TX  78723      08/18/2015     90
# 11721        Circle A  Hwy 290 E\nAustin TX  78723      08/25/2014     90
# 11871        Circle A  Hwy 290 E\nAustin TX  78723      03/16/2016     76
#
#                                                  Address  Facility ID  \
# 11074  7107 HWY 290 E\nTX Hwy 290 E Austin TX 78723\n...      2803780
# 11587  7107 HWY 290 E\nTX Hwy 290 E Austin TX 78723\n...      2803780
# 11661  7107 HWY 290 E\nTX Hwy 290 E Austin TX 78723\n...      2803780
# 11721  7107 HWY 290 E\nTX Hwy 290 E Austin TX 78723\n...      2803780
# 11871  7107 HWY 290 E\nTX Hwy 290 E Austin TX 78723\n...      2803780
#
#       Process Description
# 11074  Routine Inspection
# 11587  Routine Inspection
# 11661  Routine Inspection
# 11721  Routine Inspection
# 11871  Routine Inspection

# %% [markdown]
# Looking at zip codes, we found that two of them were parsed improperly, so we reset the zip code to be 78723 and 78741 respectively.

# %%
df.loc[df['Zip Code']=='Hwy 290 E\nAustin TX  78723', 'Zip Code'] = '78723'

# %%
df.loc[df['Zip Code']=='6\nAustin, TX  78741', 'Zip Code'] = '78741'

# %%
zip_code_counts = df['Zip Code'].value_counts()

# %%
plt.rcParams["figure.figsize"] = (20,10)
zip_code_counts.plot.bar()
plt.xlabel('Zip Code')
plt.ylabel('Number of Observations')
# Out:
# Text(0, 0.5, 'Number of Observations')

# %% [markdown]
# This chart shows the frequency of various Austin-area zip codes in the dataset. The most inspections took place in 78701, or downtown.

# %% [markdown]
# The Process Description field seems interesting. What other processes are there besides routine inspections?

# %%
df['Process Description'].value_counts()
# Out:
# Routine Inspection                        24840
# 1st Follow Up to Routine of 50 - 69         183
# 2nd Follow Up to 50 - 69                      7
# 1st Follow Up to Routine of 49 or less        3
# Name: Process Description, dtype: int64

# %% [markdown]
# It looks like any score below 70 requires a follow-up visit, and some of these inspections are follow-ups after low scores. Let's look at some of those low scores.

# %%
df[df['Score']<=49]
# Out:
#                      Restaurant Name Zip Code Inspection Date  Score  \
# 1756   Crawfish Shack and Oyster Bar    78728      06/16/2016     45
# 2719               Ichiban at Austin    78757      10/23/2015     36
# 17418           Los Comales Taqueria    78702      04/25/2014     48
# 20316       Polvo's Restaurant & Bar    78704      12/23/2015     45
#
#                                                  Address  Facility ID  \
# 1756        2013 W WELLS BRANCH PKWY\nAUSTIN, TX 78728\n     10037846
# 2719   7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 17418  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 20316  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
#
#       Process Description
# 1756   Routine Inspection
# 2719   Routine Inspection
# 17418  Routine Inspection
# 20316  Routine Inspection

# %%
df[df['Process Description']=='1st Follow Up to Routine of 49 or less']
# Out:
#                 Restaurant Name Zip Code Inspection Date  Score  \
# 3538       Los Comales Taqueria    78702      05/20/2014     70
# 15323         Ichiban at Austin    78757      10/26/2015     86
# 20044  Polvo's Restaurant & Bar    78704      01/12/2016     78
#
#                                                  Address  Facility ID  \
# 3538   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 15323  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20044  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
#
#                           Process Description
# 3538   1st Follow Up to Routine of 49 or less
# 15323  1st Follow Up to Routine of 49 or less
# 20044  1st Follow Up to Routine of 49 or less

# %% [markdown]
# Weirdly, Crawfish Shack and Oyster Bar did not have an inspection labeled "1st Follow Up to Routine of 49 of less" after scoring 45. This is something we may want to note about our data — perhaps one of the subsequent visits to Crawfish Shack and Oyster Bar has an incorrect Process Description. Now, let's look at these three restaurants - Los Comales Taqueria, Ichiban at Austin, and Polvo's Restaurant & Bar.

# %%
follow_ups = df[df['Process Description']=='1st Follow Up to Routine of 49 or less']['Restaurant Name']

# %%
df[df['Restaurant Name'].isin(follow_ups)]
# Out:
#                 Restaurant Name Zip Code Inspection Date  Score  \
# 2719          Ichiban at Austin    78757      10/23/2015     36
# 3527       Los Comales Taqueria    78702      06/01/2016     85
# 3530       Los Comales Taqueria    78702      12/21/2016     82
# 3533       Los Comales Taqueria    78702      11/19/2014     85
# 3535       Los Comales Taqueria    78702      04/09/2015     63
# 3538       Los Comales Taqueria    78702      05/20/2014     70
# 15134         Ichiban at Austin    78757      08/15/2016     79
# 15323         Ichiban at Austin    78757      10/26/2015     86
# 15411         Ichiban at Austin    78757      03/19/2014     79
# 15543         Ichiban at Austin    78757      12/16/2014     83
# 15597         Ichiban at Austin    78757      02/01/2016     75
# 15728         Ichiban at Austin    78757      06/25/2015     73
# 17301      Los Comales Taqueria    78702      09/23/2015     81
# 17418      Los Comales Taqueria    78702      04/25/2014     48
# 17475      Los Comales Taqueria    78702      04/24/2015     83
# 20029  Polvo's Restaurant & Bar    78704      09/06/2016     74
# 20044  Polvo's Restaurant & Bar    78704      01/12/2016     78
# 20316  Polvo's Restaurant & Bar    78704      12/23/2015     45
# 20345  Polvo's Restaurant & Bar    78704      03/31/2014     92
# 20484  Polvo's Restaurant & Bar    78704      05/01/2015     70
# 20499  Polvo's Restaurant & Bar    78704      03/22/2016     70
# 20561  Polvo's Restaurant & Bar    78704      10/29/2014     81
#
#                                                  Address  Facility ID  \
# 2719   7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 3527   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3530   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3533   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3535   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3538   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 15134  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15323  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15411  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15543  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15597  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15728  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 17301  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 17418  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 17475  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 20029  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20044  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20316  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20345  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20484  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20499  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20561  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
#
#                           Process Description
# 2719                       Routine Inspection
# 3527                       Routine Inspection
# 3530                       Routine Inspection
# 3533                       Routine Inspection
# 3535                       Routine Inspection
# 3538   1st Follow Up to Routine of 49 or less
# 15134                      Routine Inspection
# 15323  1st Follow Up to Routine of 49 or less
# 15411                      Routine Inspection
# 15543                      Routine Inspection
# 15597                      Routine Inspection
# 15728                      Routine Inspection
# 17301                      Routine Inspection
# 17418                      Routine Inspection
# 17475     1st Follow Up to Routine of 50 - 69
# 20029                      Routine Inspection
# 20044  1st Follow Up to Routine of 49 or less
# 20316                      Routine Inspection
# 20345                      Routine Inspection
# 20484                      Routine Inspection
# 20499                      Routine Inspection
# 20561                      Routine Inspection

# %% [markdown]
# Here, what I have done is define the series "follow-ups" to be the set of those three restaurant names, and then pulled all associated records in the dataset. We can sort alphabetically:

# %%
df[df['Restaurant Name'].isin(follow_ups)].sort_values(['Restaurant Name'])
# Out:
#                 Restaurant Name Zip Code Inspection Date  Score  \
# 2719          Ichiban at Austin    78757      2015-10-23     36
# 15728         Ichiban at Austin    78757      2015-06-25     73
# 15543         Ichiban at Austin    78757      2014-12-16     83
# 15411         Ichiban at Austin    78757      2014-03-19     79
# 15323         Ichiban at Austin    78757      2015-10-26     86
# 15134         Ichiban at Austin    78757      2016-08-15     79
# 15597         Ichiban at Austin    78757      2016-02-01     75
# 3535       Los Comales Taqueria    78702      2015-04-09     63
# 3533       Los Comales Taqueria    78702      2014-11-19     85
# 3530       Los Comales Taqueria    78702      2016-12-21     82
# 3527       Los Comales Taqueria    78702      2016-06-01     85
# 17301      Los Comales Taqueria    78702      2015-09-23     81
# 17418      Los Comales Taqueria    78702      2014-04-25     48
# 17475      Los Comales Taqueria    78702      2015-04-24     83
# 3538       Los Comales Taqueria    78702      2014-05-20     70
# 20499  Polvo's Restaurant & Bar    78704      2016-03-22     70
# 20029  Polvo's Restaurant & Bar    78704      2016-09-06     74
# 20044  Polvo's Restaurant & Bar    78704      2016-01-12     78
# 20316  Polvo's Restaurant & Bar    78704      2015-12-23     45
# 20345  Polvo's Restaurant & Bar    78704      2014-03-31     92
# 20484  Polvo's Restaurant & Bar    78704      2015-05-01     70
# 20561  Polvo's Restaurant & Bar    78704      2014-10-29     81
#
#                                                  Address  Facility ID  \
# 2719   7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15728  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15543  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15411  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15323  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15134  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15597  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 3535   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3533   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3530   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3527   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 17301  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 17418  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 17475  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3538   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 20499  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20029  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20044  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20316  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20345  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20484  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20561  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
#
#                           Process Description
# 2719                       Routine Inspection
# 15728                      Routine Inspection
# 15543                      Routine Inspection
# 15411                      Routine Inspection
# 15323  1st Follow Up to Routine of 49 or less
# 15134                      Routine Inspection
# 15597                      Routine Inspection
# 3535                       Routine Inspection
# 3533                       Routine Inspection
# 3530                       Routine Inspection
# 3527                       Routine Inspection
# 17301                      Routine Inspection
# 17418                      Routine Inspection
# 17475     1st Follow Up to Routine of 50 - 69
# 3538   1st Follow Up to Routine of 49 or less
# 20499                      Routine Inspection
# 20029                      Routine Inspection
# 20044  1st Follow Up to Routine of 49 or less
# 20316                      Routine Inspection
# 20345                      Routine Inspection
# 20484                      Routine Inspection
# 20561                      Routine Inspection

# %% [markdown]
# Or by date:

# %%
df[df['Restaurant Name'].isin(follow_ups)].sort_values(['Inspection Date'])
# Out:
#                 Restaurant Name Zip Code Inspection Date  Score  \
# 15411         Ichiban at Austin    78757      2014-03-19     79
# 20345  Polvo's Restaurant & Bar    78704      2014-03-31     92
# 17418      Los Comales Taqueria    78702      2014-04-25     48
# 3538       Los Comales Taqueria    78702      2014-05-20     70
# 20561  Polvo's Restaurant & Bar    78704      2014-10-29     81
# 3533       Los Comales Taqueria    78702      2014-11-19     85
# 15543         Ichiban at Austin    78757      2014-12-16     83
# 3535       Los Comales Taqueria    78702      2015-04-09     63
# 17475      Los Comales Taqueria    78702      2015-04-24     83
# 20484  Polvo's Restaurant & Bar    78704      2015-05-01     70
# 15728         Ichiban at Austin    78757      2015-06-25     73
# 17301      Los Comales Taqueria    78702      2015-09-23     81
# 2719          Ichiban at Austin    78757      2015-10-23     36
# 15323         Ichiban at Austin    78757      2015-10-26     86
# 20316  Polvo's Restaurant & Bar    78704      2015-12-23     45
# 20044  Polvo's Restaurant & Bar    78704      2016-01-12     78
# 15597         Ichiban at Austin    78757      2016-02-01     75
# 20499  Polvo's Restaurant & Bar    78704      2016-03-22     70
# 3527       Los Comales Taqueria    78702      2016-06-01     85
# 15134         Ichiban at Austin    78757      2016-08-15     79
# 20029  Polvo's Restaurant & Bar    78704      2016-09-06     74
# 3530       Los Comales Taqueria    78702      2016-12-21     82
#
#                                                  Address  Facility ID  \
# 15411  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20345  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 17418  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3538   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 20561  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 3533   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 15543  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 3535   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 17475  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 20484  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 15728  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 17301  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 2719   7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15323  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20316  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20044  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 15597  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20499  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 3527   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 15134  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20029  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 3530   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
#
#                           Process Description
# 15411                      Routine Inspection
# 20345                      Routine Inspection
# 17418                      Routine Inspection
# 3538   1st Follow Up to Routine of 49 or less
# 20561                      Routine Inspection
# 3533                       Routine Inspection
# 15543                      Routine Inspection
# 3535                       Routine Inspection
# 17475     1st Follow Up to Routine of 50 - 69
# 20484                      Routine Inspection
# 15728                      Routine Inspection
# 17301                      Routine Inspection
# 2719                       Routine Inspection
# 15323  1st Follow Up to Routine of 49 or less
# 20316                      Routine Inspection
# 20044  1st Follow Up to Routine of 49 or less
# 15597                      Routine Inspection
# 20499                      Routine Inspection
# 3527                       Routine Inspection
# 15134                      Routine Inspection
# 20029                      Routine Inspection
# 3530                       Routine Inspection

# %% [markdown]
# But wait! Because the data type of Inspection Date is a string, we've sorted the dates alphabetically instead of in chronological order. We need to convert the Inspection Date to dates. I'll write a function to convert the date strings to dates, and then I'll apply that function for every row in small_df.

# %%
from datetime import datetime

def change_date_string_to_date(date_string):
    date = datetime.strptime(date_string, "%m/%d/%Y")
    return date

test = change_date_string_to_date("12/02/2014")
print(test, type(test))
# Out:
# 2014-12-02 00:00:00 <class 'datetime.datetime'>

# %%
df['Inspection Date'] = df['Inspection Date'].apply(lambda d: change_date_string_to_date(d))

# %%
df[df['Restaurant Name'].isin(follow_ups)].sort_values(['Inspection Date'])
# Out:
#                 Restaurant Name Zip Code Inspection Date  Score  \
# 15411         Ichiban at Austin    78757      2014-03-19     79
# 20345  Polvo's Restaurant & Bar    78704      2014-03-31     92
# 17418      Los Comales Taqueria    78702      2014-04-25     48
# 3538       Los Comales Taqueria    78702      2014-05-20     70
# 20561  Polvo's Restaurant & Bar    78704      2014-10-29     81
# 3533       Los Comales Taqueria    78702      2014-11-19     85
# 15543         Ichiban at Austin    78757      2014-12-16     83
# 3535       Los Comales Taqueria    78702      2015-04-09     63
# 17475      Los Comales Taqueria    78702      2015-04-24     83
# 20484  Polvo's Restaurant & Bar    78704      2015-05-01     70
# 15728         Ichiban at Austin    78757      2015-06-25     73
# 17301      Los Comales Taqueria    78702      2015-09-23     81
# 2719          Ichiban at Austin    78757      2015-10-23     36
# 15323         Ichiban at Austin    78757      2015-10-26     86
# 20316  Polvo's Restaurant & Bar    78704      2015-12-23     45
# 20044  Polvo's Restaurant & Bar    78704      2016-01-12     78
# 15597         Ichiban at Austin    78757      2016-02-01     75
# 20499  Polvo's Restaurant & Bar    78704      2016-03-22     70
# 3527       Los Comales Taqueria    78702      2016-06-01     85
# 15134         Ichiban at Austin    78757      2016-08-15     79
# 20029  Polvo's Restaurant & Bar    78704      2016-09-06     74
# 3530       Los Comales Taqueria    78702      2016-12-21     82
#
#                                                  Address  Facility ID  \
# 15411  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20345  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 17418  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 3538   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 20561  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 3533   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 15543  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 3535   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 17475  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 20484  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 15728  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 17301  2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 2719   7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 15323  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20316  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 20044  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 15597  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20499  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 3527   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
# 15134  7310 BURNET RD\nAUSTIN, TX 78757\n(30.349328, ...     10215188
# 20029  2004 S 1ST ST\nAUSTIN, TX 78704\n(30.245099, -...      2801085
# 3530   2136 E 7TH ST\nAUSTIN, TX 78702\n(30.26165, -9...      2800923
#
#                           Process Description
# 15411                      Routine Inspection
# 20345                      Routine Inspection
# 17418                      Routine Inspection
# 3538   1st Follow Up to Routine of 49 or less
# 20561                      Routine Inspection
# 3533                       Routine Inspection
# 15543                      Routine Inspection
# 3535                       Routine Inspection
# 17475     1st Follow Up to Routine of 50 - 69
# 20484                      Routine Inspection
# 15728                      Routine Inspection
# 17301                      Routine Inspection
# 2719                       Routine Inspection
# 15323  1st Follow Up to Routine of 49 or less
# 20316                      Routine Inspection
# 20044  1st Follow Up to Routine of 49 or less
# 15597                      Routine Inspection
# 20499                      Routine Inspection
# 3527                       Routine Inspection
# 15134                      Routine Inspection
# 20029                      Routine Inspection
# 3530                       Routine Inspection

# %% [markdown]
# That works! Finally, I'll save this subset of our dataframe (records only associated with these three restaurants) as its own object, and create a plot using another popular plotting package in Python, called Seaborn: https://seaborn.pydata.org/index.html

# %%
import seaborn as sns

three_restaurants = df[df['Restaurant Name'].isin(follow_ups)]

sns.lineplot(data=three_restaurants, x='Inspection Date', y='Score', hue='Restaurant Name')
plt.legend()
plt.xticks(rotation=45)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (array([735354., 735477., 735599., 735719., 735842., 735964., 736085.,
#         736208., 736330.]), <a list of 9 Text xticklabel objects>)

# %% [markdown]
# Try finding a restaurant you've been to in the dataset and plotting their inspection scores over time!
